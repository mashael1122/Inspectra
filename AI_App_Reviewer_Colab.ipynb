# %% [markdown]
# # AI App Reviewer — Colab Launcher\nUse a Colab runtime for demonstration. For full production use, deploy the Docker Compose stack.

# %%
# !git clone YOUR_GITHUB_REPOSITORY_URL ai-app-reviewer\n%cd ai-app-reviewer\n!pip install -q -r requirements.txt\n!playwright install chromium --with-deps

# %%
import os, getpass\nos.environ['OPENAI_API_KEY']=getpass.getpass('OPENAI_API_KEY: ')\nos.environ['OPENAI_MODEL']='gpt-5.2'

# %%
import subprocess, time\napi=subprocess.Popen(['uvicorn','app.api:app','--host','0.0.0.0','--port','8000'])\ntime.sleep(4)\nprint('API started on port 8000')
